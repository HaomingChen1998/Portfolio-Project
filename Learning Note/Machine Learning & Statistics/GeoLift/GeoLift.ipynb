# %% [markdown]
# - Due in 3 weeks (10/25)

# %% [markdown]
# # Coding Environment
# Python 3.12.0
# NumPy 1.26.0
# Pandas 2.1.1

# %% [markdown]
# ![WINWORD_X6A83xb5Yp.png](attachment:WINWORD_X6A83xb5Yp.png)

# %% [markdown]
# <img src="data:image/png;base64,..." alt="image" iscopyblocked="false">

# %% [markdown]
# https://github.com/facebookincubator/GeoLift/blob/main/R/pre_test_power.R

# %% [markdown]
# Task 3 (3 weeks+ along with Task 4). Power Analysis Part 1 – data services (Robbie, Cody)
# Recreate GeoLiftMarketSelection’s data services part including the MarketSelection and MarketMatching functions. The MarketMatching may require research into the workings of the R library.
#
# Task 4. Power Analysis Part 2 – simulation loop (Robbie, Cody)
# Recreate GeoLiftMarketSelection’s power analysis simulation loop including stochastic_market_selector, run_simulations, type_of_test, and pvalueCalc functions. Also, implement the GeoLiftPower function as it is similar to a single instance of the loop.
